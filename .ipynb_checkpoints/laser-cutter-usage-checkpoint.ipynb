# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

lasercuts = pd.read_csv('laser-cutter-event-307-log-2021-06-11.csv', sep='\t', parse_dates=['Date and Time'])
lasercuts['date'] = lasercuts['Date and Time'].dt.date

axs = lasercuts['date'].value_counts().plot(figsize=(20, 10))
axs.set_ylabel('laser jobs per day')
# Out:
# Text(0, 0.5, 'laser jobs per day')
